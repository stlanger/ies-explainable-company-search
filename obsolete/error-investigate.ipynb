# %%
import pickle

# payloads = []
# for i in range(2,12):
#     with open(f"logs/error-payloads_{i}.pkl", "rb") as f:
#         payloads = pickle.load(f) 
#         print(payloads[0]["crefodata"]["name"])

with open("logs/error-payloads_1012.pkl", "rb") as f:
    print(pickle.load(f))
# Out:
# [{'filepath': '/local/innecs-local/website-data/3130121960_sundb-halle-de/datenschutz-impressum.txt', 'filename': 'datenschutz-impressum.txt', 'crefoid': '3130121960', 'name': 'S &amp; B Montagen GmbH Halle', 'idx': 0, 'text': '\uf041\xa0S & B GmbH, Trothaer Straße 43a, D-06118 Halle (Saale)\n\n\uf098\xa00345 478847-0\xa0 \xa0 \xa0\uf1ac\xa00345 478847-28\n\n\xa0\xa0\uf0e0\xa0info@sundb-halle.de\n\n\uf046\xa0WERBETÜRME\n\nBlickfang und Wegweiser\n\n\uf046\xa0STAHLBAU\n\nStahlkonstruktionen\n\n\uf046\xa0SCHWEISS-ARBEITE\n\nMIG/MAG, E-Hand, WIG uvm.\n\nHomeÜber unsLeistungen\nReferenzen\nJobs und KarriereDigital Innovation (EFRE)', 'crefodata': {'file': 'cache/06118/60/3130121960_S_B_MONTAGEN_GMBH_HALLE.html', 'filetime': '2023-09-19T15:28:05.725Z', 'origin': 'https://firmeneintrag.creditreform.de/06118/3130121960/S_B_MONTAGEN_GMBH_HALLE', 'crefonummer': '3130121960', 'postalcode': '06118', 'code': '43.99.9', 'zweck': 'Planung, Durchführung, Herstellung und Vertrieb von Stahlbau-, Fass
# ...

# %%
p = payloads[0]["crefodata"]["name"]
# p["name"]
p
# Out:
# 'Altmarkkreis Salzwedel'

# %%
print(p.get("filename"))
# Out:
# buerger-presseservice-presseservice-pressemitteilungen-neuigkeiten-pressebilder-aspx.txt
