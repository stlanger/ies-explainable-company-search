# %%
import os
import sys

import json
import re
import torch

import transformers
from transformers import AutoTokenizer, AutoModelForCausalLM
from sentence_transformers import SentenceTransformer

sys.path.append("../")
sys.path.append("../loaders/")
from rag_utils import RAG_Utils

from config import Config
cfg = Config("uk")

from qdrant_utils import Qdrant
qdrant = Qdrant(cfg.QDRANT_URL, cfg.QDRANT_WEBSITES, SentenceTransformer(cfg.SENTENCE_TRANSFORMER))
# Out:
# using the following configuration:
#
# The Config objects offers the following variables
# ------ WEBSITE STORAGE ----------
# WEBSITE_STORAGE_PATH    /local/innecs-local/uk-website-data
#
# ------ QDRANT VECTOR STORE ------
# QDRANT_URL url:         http://qdrant:6333
# QDRANT_WEBSITES:      ies_uk_website_sentences
# QDRANT_WEBSITES_SUMMARIES:      ies_uk_website_summaries
#
# ------ JSON_DATA ----------------
# JSON_FILE_PATH:         /local/innecs-local/uk-website-data.json
# JSON_COMPANY_ID:        company_id
# JSON_COMPANY_NAME:      company_name
# JSON_COMPANY_URL:      weburl
#
# ------ SQLITE -------------------
# SQLITE_FILEPATH:        /local/innecs-local/db/rag-tasks-uk.db
#
# ------ NLP ----------------------
# SPACY_MODEL:            en_core_web_lg
# SENTENCE_TRANSFORMER:   all-MiniLM-L6-v2
# LLM:                    meta-llama/Meta-Llama-3.1-8B-Instruct
# /home/dev/git/ies/retrieval-augmented-exploration/website-rag/playground/../loaders/qdrant_utils.py:11: UserWarning: Qdrant client version 1.14.2 is incompatible with server version 1.12.6. Major versions should match and minor version difference must not exceed 1. Set check_compatibility=False to skip version check.
#   self.qdrant = QdrantClient(url, timeout=600000)

# %%
rag = RAG_Utils(cfg)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Device set to use cuda:0

# %%
answer = rag.generate_company_summary("12104755")
print(answer)
# Out:
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# {'company_name': 'NEPTUNO MANAGEMENT LTD', 'company_id': '12104755', 'weburl': 'http://www.bestinternationalgroup.com', 'category': 'Private Limited Company', 'status': 'Active', 'incorporation_date': '15/07/2019', 'country_of_origin': 'United Kingdom', 'address_posttown': 'KNUTSFORD', 'address_postcode': 'WA16 8RB', 'address_country': 'ENGLAND', 'address_lines': ['MOSELEY HALL FARM', 'CHELFORD ROAD'], 'sic_code_texts': ['82990 - Other business support service activities n.e.c.'], 'storage_folder': '12104755_bestinternationalgroup-com', 'summary': 'Best International Group is a leading provider of business services to companies seeking investment capital and looking to manage their capital more effectively. The company helps clients access new investment capital and provides investment administration services to help them develop their businesses. \n\nHeadquartered in Knutsford, Cheshire, UK, the company has a selective nature and focus on doing the right thing in a highly regulated financial services sector. \n\nTheir services include investment capital, investment administration, and investor relationship management, as well as market insights and alternative investment market information.'}

# %%
answer = rag.generate_company_summary("09200687")
print(answer)
# Out:
# {'company_name': 'DEEP WEB RESEARCH LTD', 'company_id': '09200687', 'weburl': 'http://deepwebresearch.co.uk', 'category': 'Private Limited Company', 'status': 'Active', 'incorporation_date': '02/09/2014', 'country_of_origin': 'United Kingdom', 'address_posttown': 'LONDON', 'address_postcode': 'W1F 0JH', 'address_lines': ['15 INGESTRE PLACE'], 'sic_code_texts': ['63990 - Other information service activities n.e.c.'], 'storage_folder': '09200687_deepwebresearch-co-uk', 'summary': 'Deep Web Research Ltd offers services in extracting valuable information from the deep web, a part of the internet not indexed by major search engines. Their services include:\n\n- Regular scanning of deep web sources for timely information\n- Training on the use of deep web search tools\n- Setting up deep web search tools for clients\n- Deep web search tools used for various applications, including supplier/partner due diligence, monitoring product fraud, and detecting fraud and corruption.\n\nThe company is based in England and Wales, with a registered address in London.'}

# %%
answer = rag.generate_company_summary("10539203")
print(answer)
# Out:
# further shortening...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 answer = rag.generate_company_summary("10539203")
#       2 print(answer)
#
# File ~/git/ies/retrieval-augmented-exploration/website-rag/playground/../rag_utils.py:265, in RAG_Utils.generate_company_summary(self, company_id, show_company_data)
#     263 def generate_company_summary(self, company_id, show_company_data=True):
#     264     company_fulltext = self.qdrant.get_company_fulltext(company_id)
# --> 265     summary = self._recursively_summarize_company_text(company_fulltext)
#     266     if not show_company_data:
#     267         return summary
#
# File ~/git/ies/retrieval-augmented-exploration/website-rag/playground/../rag_utils.py:260, in RAG_Utils._recursively_summarize_company_text(self, text, last_word_number)
#     258 else:
#     259     print("further shortening...")
# --> 260     return self.recursively_summarize_company_text(answer, word_count)
#
# AttributeError: 'RAG_Utils' object has no attribute 'recursively_summarize_company_text'
