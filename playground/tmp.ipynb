# %%
sys_prompt = """You will be provided with all the text of a company's website. Your job is to create a very concise summary about the company's portfolio. 
While doing this, be as brief as possible and only include the most important information, like:
1. A short overview of the unique services or products the company offers.
2. The company's hometown (without full addresses) or key locations.
You will avoid any promotional or marketing language. You will not include any information about the website, disclaimers or contract information. You do not address us in your answer, nor include any greetings."""


sys_prompt
# Out:
# "You will be provided with all the text of a company's website. Your job is to create a very concise summary about the company's portfolio. \nWhile doing this, be as brief as possible and only include the most important information, like:\n1. A short overview of the unique services or products the company offers.\n2. The company's hometown (without full addresses) or key locations.\nYou will avoid any promotional or marketing language. You will not include any information about the website, disclaimers or contract information. You do not address us in your answer, nor include any greetings."

# %%
sys_prompt = """Dir wird der gesamte Text der Website eines Unternehmens zur Verfügung gestellt. Deine Aufgabe ist es, eine sehr knappe Zusammenfassung über das Portfolio des Unternehmens auf deutsch zu erstellen. 
Sei dabei so kurz wie möglich und beziehe nur die wichtigsten Informationen ein, wie:
1. Eine kurze Übersicht über die einzigartigen Dienstleistungen oder Produkte, die das Unternehmen anbietet.
2. Die Heimatstadt des Unternehmens oder wichtige Standorte (Ortsnamen ohne vollständige Adresse).
Du vermeidest jegliche werbende oder marketingorientierte Sprache. Du wirst keine Informationen über den Aufbau oder Inhalt der Website, rechtliche Hinweise oder Vertragsinformationen in die Unternehmensbeschreibung aufnehmen. Du sprichst uns nicht direkt an und fügst keine Begrüßungen hinzu."""









print(sys_prompt)
# Out:
# Dir wird der gesamte Text der Website eines Unternehmens zur Verfügung gestellt. Deine Aufgabe ist es, eine sehr knappe Zusammenfassung über das Portfolio des Unternehmens auf deutsch zu erstellen.
# Sei dabei so kurz wie möglich und beziehe nur die wichtigsten Informationen ein, wie:
# 1. Eine kurze Übersicht über die einzigartigen Dienstleistungen oder Produkte, die das Unternehmen anbietet.
# 2. Die Heimatstadt des Unternehmens oder wichtige Standorte (Ortsnamen ohne vollständige Adresse).
# Du vermeidest jegliche werbende oder marketingorientierte Sprache. Du wirst keine Informationen über den Aufbau oder Inhalt der Website, rechtliche Hinweise oder Vertragsinformationen in die Unternehmensbeschreibung aufnehmen. Du sprichst uns nicht direkt an und fügst keine Begrüßungen hinzu.

# %%
# lines = {}
# with open("/home/dev/git/ies/retrieval-augmented-exploration/website-rag/logs/failed_companies.txt", "r") as f:
#     lines = {line.rstrip() for line in f}
# #     print(lines)
# #     print()
# #     lines.add("08461551")
# #     print(lines)
    
# "09711089" in lines
import math
c = 500000 
c *= 0.9
math.floor(c)
# Out:
# 450000

# %%
s = ([Record(id='d4f0e7fe-b4ad-45aa-9078-f186f45e4c28', payload={'company_id': '12072947', 'name': 'LONDON LOOP LTD', 'company_data': {'company_name': 'LONDON LOOP LTD', 'company_id': '12072947', 'weburl': 'http://loopknitting.com', 'category': 'Private Limited Company', 'status': 'Active', 'incorporation_date': '27/06/2019', 'country_of_origin': 'United Kingdom', 'address_posttown': 'LONDON', 'address_postcode': 'E6 5AQ', 'address_country': 'ENGLAND', 'address_lines': ['FLAT 20', '10 MAHINDRA WAY'], 'sic_code_texts': ['68320 - Management of real estate on a fee or contract basis'], 'storage_folder': '12072947_loopknitting-com'}, 'fulltext_character_length': 215516, 'summary': "Loop is a renowned yarn shop in London, offering a vast collection of natural fibers, hand-dyed yarns, and haberdashery sourced from around the world. Their extensive range includes various yarn weights, fibers, and brands, as well as unique items like handmade buttons and vintage accessories. \n\nLoop has been recognized as the best Independent Knitting shop in London, reflecting their dedication to textiles and commitment to quality. The shop features a physical location in Camden Passage, Islington, London, where customers can explore their vast collection and receive expert advice. \n\nTheir website provides an easy-to-navigate platform for customers to browse and purchase yarns and haberdashery, with a blog offering tips, tutorials, and news about the latest products. Loop's passion for textiles and commitment to quality make them a leader in the industry, making them a must-visit destination for anyone who loves yarns and haberdashery."}, vector=None, shard_key=None, order_value=None), Record(id='eeb1b688-a7a9-41eb-91ae-186517957903', payload={'company_id': 'SC775794', 'name': 'SEADYES LIMITED', 'company_data': {'company_name': 'SEADYES LIMITED', 'company_id': 'SC775794', 'weburl': 'http://seadyes.com', 'category': 'Private Limited Company', 'status': 'Active', 'incorporation_date': '14/07/2023', 'country_of_origin': 'United Kingdom', 'address_posttown': 'EDINBURGH', 'address_postcode': 'EH12 5HD', 'address_country': 'SCOTLAND', 'address_lines': ['CITYPOINT', '3RD FLOOR, 65 HAYMARKET TERRACE'], 'sic_code_texts': ['20120 - Manufacture of dyes and pigments', '72110 - Research and experimental development on biotechnology'], 'storage_folder': 'SC775794_seadyes-com'}, 'fulltext_character_length': 3455, 'summary': "SeaDyes is a company developing a scalable and fully traceable seaweed-based dye innovation for fashion and textiles. The company applies marine science, biotechnology, and sustainable aquaculture to create a sustainable alternative to synthetic dyes. Every year, around 280,000 tonnes of synthetic dyes are released into the environment, contributing to negative impacts on health, biodiversity, and climate.\n\nThe company's technology offers an alternative pathway to detoxify and decarbonise the dyeing and wet processing of textiles. SeaDyes' biobased colours provide flexible, creative possibilities for textiles and work towards circular sustainability in fashion. The company's Biomass Sustainability Strategy is founded on three pillars: environmental, social, and economic, supported by strong governance.\n\nSeaweed is chosen as the primary resource due to its renewable nature, ability to store carbon, and provide habitat and clean water. SeaDyes has partnered with the James Hutton Institute, a leading scientific research institute, to accelerate research and commercialisation efforts. The company aims to scale up its breakthrough technology, develop market-ready products, and contribute to Scotland's growing bioeconomy."}, vector=None, shard_key=None, order_value=None)], None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ...
